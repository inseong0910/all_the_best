# %%
# 1 hist() 함수
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %%
# 2 주사위 시뮬레이션
# 2-1. 주사위를 굴린다
# 2-2. 나온 결과를 기록한다
# 2-3. 2-1~2-2 과정을 n번 반복한다
# 2-4. 주사위의 눈이 나온 횟수를 히스토그램으로 그린다

import random
print(random.randint(1, 6))
# Out:
# 6

# %%
# 주사위를 여러 번 굴리는 상황을 for 반복문으로 표현
import random
dice = []
for i in range(5):
    dice.append(random.randint(1, 6))
print(dice)
# Out:
# [4, 6, 6, 6, 3]

# %%
# 주사위를 100번 굴리는 상황
import random
dice = []
for i in range(100):
    dice.append(random.randint(1, 6))
print(dice)
# Out:
# [3, 1, 5, 1, 5, 3, 1, 6, 6, 6, 1, 5, 4, 2, 3, 1, 3, 2, 6, 2, 1, 3, 5, 1, 3, 6, 5, 2, 1, 6, 5, 3, 1, 3, 2, 5, 6, 3, 2, 1, 1, 3, 4, 3, 2, 1, 6, 1, 1, 3, 5, 6, 5, 4, 4, 3, 2, 5, 3, 1, 2, 6, 3, 4, 4, 6, 3, 4, 4, 6, 1, 4, 5, 5, 6, 2, 5, 6, 2, 2, 1, 2, 3, 5, 2, 5, 4, 5, 1, 3, 6, 1, 1, 1, 5, 1, 4, 5, 2, 3]

# %%
import matplotlib.pyplot as plt
dice = []
for i in range(100):
    dice.append(random.randint(1, 6))
plt.hist(dice, bins = 6)
plt.show()

# %%
import matplotlib.pyplot as plt
dice = []
for i in range(10000):
    dice.append(random.randint(1, 6))
plt.hist(dice, bins = 6)
plt.show()

# %%
import matplotlib.pyplot as plt
dice = []
for i in range(1000000):
    dice.append(random.randint(1, 6))
plt.hist(dice, bins = 6)
plt.show()

# %%
# 반복 실행 횟수가 1~6까지 거의 1/6씩 균등한 빈도로 나온 것을 확인할 수 있음

# %%
# 기온 데이터를 히스토그램으로 표현하기

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))
        
plt.hist(result, bins = 100, color = 'r')
plt.show()

# %%
# 8월 기온 데이터만 뽑아서 히스토그램으로 표현하기

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []   # 8월 최고 기온 값을 저장할 aug 리스트 생성

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
            
plt.hist(aug, bins = 100, color = 'r')
plt.show()

# %%
# 1월과 8월 데이터를 히스토그램으로 시각화하기

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)

aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '':
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))
            
plt.hist(aug, bins = 100, color = 'r', label = 'Aug')
plt.hist(jan, bins = 100, color = 'b', label = 'Jan')
plt.legend() # 그래프에 범례를 달고 싶을 때 사용하는 함수
plt.show()

# %%
# 기온 데이터를 상자 그림으로 표현하기
# 상자 그림 : 자료에서 얻어낸 최댓값, 최솟값, 상위 1/4, 2/4, 3/4에 위치한 값을 보여주는 그래프

import matplotlib.pyplot as plt
import random
result = []
for i in range(13) :
    result.append(random.randint(1, 1000))
print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# [76, 96, 110, 379, 483, 542, 642, 671, 692, 798, 860, 946, 967]

# %%
# 다른 위치 1/4, 2/4, 3/4 위치의 정확한 값이 알고 싶다면?
import numpy as np
result = np.array(result)
print("1/4: "+str(np.percentile(result, 25)))
print("2/4: "+str(np.percentile(result, 50)))
print("3/4: "+str(np.percentile(result, 75)))
# Out:
# 1/4: 379.0
# 2/4: 642.0
# 3/4: 798.0

# %%
# 서울 최고 기온 데이터를 상자 그림으로 그리기

import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '':
        result.append(float(row[-1]))
        
import matplotlib.pyplot as plt
plt.boxplot(result) # 상자 그림으로 나타내기
plt.show()

# %%
# 1월과 8월의 상자 그림
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)

aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08' :
            aug.append(float(row[-1]))
        if month == '01' :
            jan.append(float(row[-1]))
            
import matplotlib.pyplot as plt
plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
plt.boxplot([aug, jan])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x230a6cd3d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x230a6d26430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x230a6cd3a90>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x230a6d26a60>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x230a6d26d90>,
# ...
#  'means': []}

# %%
import matplotlib.pyplot as plt
import csv

f = open('seoul.csv')
data = csv.reader(f)
next(data)

# 월별 데이터를 저장할 리스트 month 생성(12개)
month = [[], [], [], [], [], [], [], [], [], [], [], []]

for row in data :
    if row[-1] != '' :
        # 월과 같은 번호의 인덱스에 월별 데이터 저장(예 : 1월 -> month[0])
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))
        
plt.boxplot(month)
plt.show()

# %%
# 8월 일별 기온 데이터를 상자 그림으로 표현하기

import matplotlib.pyplot as plt
import csv

f = open('seoul.csv')
data = csv.reader(f)
next(data)

day = []
for i in range(31):
    day.append([]) # day 리스트 내 31개의 리스트 생성
    
for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '08' : # 8월이라면
            day[int(row[0].split('-')[2])-1].append(float(row[-1]))
            
plt.style.use('ggplot') # 그래프 스타일 지정
plt.figure(figsize = (10,5), dpi = 300) # 그래프 크기 수정
plt.boxplot(day, showfliers = False) # 아웃라이어 값 생략

plt.show()
